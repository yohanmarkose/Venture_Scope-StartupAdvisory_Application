# %%
import pandas as pd
import snowflake.connector
import yfinance as yf
import numpy as np
import datetime
import time
from dotenv import load_dotenv
import os

load_dotenv()

conn_params = {
    'user': os.getenv('SNOWFLAKE_USER'),
    'password': os.getenv('SNOWFLAKE_PASSWORD'),
    'account': os.getenv('SNOWFLAKE_ACCOUNT'),
    'warehouse': os.getenv('SNOWFLAKE_WAREHOUSE'),
    'database': os.getenv('SNOWFLAKE_DATABASE'),
    'schema': os.getenv('SNOWFLAKE_SCHEMA'),
    'role': os.getenv('SNOWFLAKE_ROLE')
}

# %%
def connect_to_snowflake(params):
    try:
        conn = snowflake.connector.connect(
            user=params['user'],
            password=params['password'],
            account=params['account'],
            warehouse=params['warehouse'],
            database=params['database'],
            schema=params['schema'],
            role=params['role']  # Specify the role if needed
        )
        print("Connected to Snowflake successfully!")
        return conn
    except Exception as e:
        print(f"Error connecting to Snowflake: {e}")
        return None

# %%
conn = connect_to_snowflake(conn_params)

if conn is None:
    print("Failed to connect to Snowflake. Exiting.")
# Out:
# Connected to Snowflake successfully!

# %% [markdown]
# ## Table updation with YFINANCE

# %%
def create_table_in_snowflake(conn, table_name="LARGE_COMPANY_DATA_FINAL", schema="OPPORTUNITY_ANALYSIS.MARKET_ANALYSIS"):
    create_query = f"""
    CREATE OR REPLACE TABLE {schema}.{table_name} (
        ID VARCHAR,
        COMPANY_NAME VARCHAR,
        INDUSTRY VARCHAR,
        SIZE VARCHAR,
        FOUNDED NUMBER,
        REGION VARCHAR,
        COUNTRY VARCHAR,
        LOCALITY VARCHAR,
        WEBSITE VARCHAR,
        LINKEDIN_URL VARCHAR,
        COMPANY_AGE NUMBER,
        SIZE_CATAGORY VARCHAR,
        PERFORMANCE_CATEGORY VARCHAR,
        PERFORMANCE_SCORE FLOAT,
        T_SYMBOL VARCHAR,
        TICKER VARCHAR,
        CURRENT_PRICE FLOAT,
        MARKET_CAP NUMBER,
        YEARLY_RETURN NUMBER,
        VOLATILITY VARCHAR
    );
    """
    try:
        cursor = conn.cursor()
        cursor.execute(create_query)
        print(f"Table {schema}.{table_name} created or replaced.")
    except Exception as e:
        print(f"Error creating table: {e}")
    finally:
        cursor.close()

def save_df_to_snowflake(df, table_name="LARGE_COMPANY_DATA_FINAL", database="OPPORTUNITY_ANALYSIS", schema="MARKET_ANALYSIS"):
    conn = connect_to_snowflake(conn_params)
    if conn is None:
        print("❌ Could not connect to Snowflake.")
        return

    try:
        conn.cursor().execute(f"USE DATABASE {database}")
        conn.cursor().execute(f"USE SCHEMA {schema}")

        df.columns = [col.upper() for col in df.columns]

        create_table_in_snowflake(conn, table_name, f"{database}.{schema}")

        # Write data using uppercase column names
        success, nchunks, nrows, _ = write_pandas(conn, df, table_name=table_name, schema=schema)

        if success:
            print(f"✅ Successfully inserted {nrows} rows into {database}.{schema}.{table_name}")
        else:
            print(f"❌ Failed to write DataFrame to Snowflake")

    except Exception as e:
        print(f"❌ Error writing DataFrame to Snowflake: {e}")
    finally:
        conn.close()

# %%
def get_company_data():
    """Fetch company data with ticker symbols from Snowflake"""
    conn = connect_to_snowflake(conn_params)
    if conn is None:
        return None
    
    try:
        query = """
        SELECT * FROM LARGE_COMPANIES_WITH_TICKER
        WHERE T_SYMBOL IS NOT NULL
        """
        
        df = pd.read_sql(query, conn)
        conn.close()
        print(f"Retrieved {len(df)} companies with ticker symbols")
        return df
    except Exception as e:
        print(f"Error fetching company data: {e}")
        if conn:
            conn.close()
        return None

def get_yfinance_metrics(ticker_list):
    """Get relevant financial metrics for a list of tickers"""
    # Filter out None values
    ticker_list = [t for t in ticker_list if t]
    
    if not ticker_list:
        return pd.DataFrame()
    results = {}
    batch_size = 15
    for i in range(0, len(ticker_list), batch_size):
        batch = ticker_list[i:i+batch_size]
        print(f"Processing batch {i//batch_size + 1}/{(len(ticker_list) + batch_size - 1)//batch_size}")
        
        for ticker in batch:
            try:
                ticker_obj = yf.Ticker(ticker)
                info = ticker_obj.info
                hist = ticker_obj.history(period="1y")
                if len(hist) > 0:
                    start_price = hist['Close'].iloc[0]
                    current_price = hist['Close'].iloc[-1]
                    yearly_return = ((current_price - start_price) / start_price) * 100
                    daily_returns = hist['Close'].pct_change().dropna()
                    volatility = daily_returns.std() * 100 * np.sqrt(252)  # Annualized
                else:
                    yearly_return = None
                    volatility = None
                
                # Store the results
                results[ticker] = {
                    'ticker': ticker,
                    'current_price': current_price,
                    'market_cap': info.get('marketCap', None),
                    'yearly_return': yearly_return,
                    'volatility': volatility,
                }
                time.sleep(0.1)  # To avoid hitting the API too fast
                
            except Exception as e:
                print(f"Error processing ticker {ticker}: {e}")
                # Add the ticker to results with None values to maintain the record
                results[ticker] = {
                    'ticker': ticker,
                    'current_price': None,
                    'market_cap': None,
                    'yearly_return': None,
                    'volatility': None
                }
    
    metrics_df = pd.DataFrame.from_dict(results, orient='index')
    return metrics_df

def enhance_company_data_with_yfinance():
    company_df = get_company_data()
    
    if company_df is None or company_df.empty:
        print("No company data available. Exiting.")
        return

    ticker_symbols = company_df['T_SYMBOL'].unique().tolist()
    print(f"Found {len(ticker_symbols)} unique ticker symbols")
    
    metrics_df = get_yfinance_metrics(ticker_symbols)
    
    if metrics_df.empty:
        print("No metrics data retrieved. Exiting.")
        return
    
    enhanced_df = pd.merge(
        company_df,
        metrics_df,
        left_on='T_SYMBOL',
        right_on='ticker',
        how='left'
    )
    enhanced_df = enhanced_df.drop(columns=['ticker'])
    
    print(f"Enhanced dataset has {enhanced_df.shape[1]} columns and {enhanced_df.shape[0]} rows")
    
    # Write the enhanced data back to Snowflake
    save_df_to_snowflake(enhanced_df)
    
    return enhanced_df

# %%
en_df = enhance_company_data_with_yfinance()
# Out:
# Connected to Snowflake successfully!
# C:\Users\yohan\AppData\Local\Temp\ipykernel_21096\657144211.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# Retrieved 2007 companies with ticker symbols
# Found 1782 unique ticker symbols
# Processing batch 1/90
# Processing batch 2/90
# Processing batch 3/90
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/CELG.R?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=CELG.R&crumb=3JMyOGxXE8v
# Error processing ticker CELG.R: 'NoneType' object has no attribute 'update'
# Processing batch 4/90
# Processing batch 5/90
# Processing batch 6/90
# Processing batch 7/90
# Processing batch 8/90
# Processing batch 9/90
# Processing batch 10/90
# Processing batch 11/90
# Processing batch 12/90
# Processing batch 13/90
# Processing batch 14/90
# Processing batch 15/90
# Processing batch 16/90
# Processing batch 17/90
# Processing batch 18/90
# Processing batch 19/90
# Processing batch 20/90
# Processing batch 21/90
# Processing batch 22/90
# Processing batch 23/90
# Processing batch 24/90
# Processing batch 25/90
# Processing batch 26/90
# Processing batch 27/90
# Processing batch 28/90
# Processing batch 29/90
# Processing batch 30/90
# Processing batch 31/90
# Processing batch 32/90
# Processing batch 33/90
# Processing batch 34/90
# Processing batch 35/90
# Processing batch 36/90
# Processing batch 37/90
# Processing batch 38/90
# Processing batch 39/90
# Processing batch 40/90
# Processing batch 41/90
# Processing batch 42/90
# Processing batch 43/90
# Processing batch 44/90
# Processing batch 45/90
# Processing batch 46/90
# Processing batch 47/90
# Processing batch 48/90
# Processing batch 49/90
# $MOG.A: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# Processing batch 50/90
# Processing batch 51/90
# Processing batch 52/90
# Error processing ticker PSCU: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HLI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ITW: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ILMN: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker MDXG: Too Many Requests. Rate limited. Try after a while.
# Processing batch 53/90
# Error processing ticker PGHL: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker DBMF: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker SHIM: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker INCY: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker INR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker INFA: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker IR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker IMKTA: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker INGM: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker INGR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker INOD: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker IOSP: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker INNV: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker INVX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NOTV: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NSIT: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NSP: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker WWJD: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker INSP: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker IBP: Too Many Requests. Rate limited. Try after a while.
# Processing batch 54/90
# Error processing ticker PODD: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CSGP: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker COST: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker COTY: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker COUR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CVLG: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PMTS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CPSH: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CBRL: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CRD.A: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CACC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker XJH: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CRML: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CROX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CCRN: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CAPL: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker XOVR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CCI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CCK: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker XVOL: Too Many Requests. Rate limited. Try after a while.
# Processing batch 55/90
# Error processing ticker CYRX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CCTG: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker KWEB: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CSWI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CSX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CUBE: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CULP: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CPIX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CMI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CMLS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CW: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CWK: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CTOS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CVI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CVS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EME: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EBS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker MSN: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker GBLI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OGCP: Too Many Requests. Rate limited. Try after a while.
# Processing batch 56/90
# Error processing ticker EHC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ECPG: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ENR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EPAC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ENS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EBF: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ENVA: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ENPH: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NPO: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ENTG: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EAI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EPD: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker IVT: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NVST: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EOG: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker BNDI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EPAM: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EEIQ: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker TFPN: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EPSN: Too Many Requests. Rate limited. Try after a while.
# Processing batch 57/90
# Error processing ticker EFX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EQIX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EQX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ELS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EQR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker AMBP.W: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker COLD: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker SIGIP: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NANR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker MSB: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HRTS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ECDA: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker APUE: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker WOW: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ETSY: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EEFT: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EVCM: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EVR: Too Many Requests. Rate limited. Try after a while.
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/CALX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=CALX&crumb=Edge%3A+Too+Many+Requests
# Error processing ticker CALX: 'NoneType' object has no attribute 'update'
# Processing batch 58/90
# Processing batch 59/90
# Processing batch 60/90
# Processing batch 61/90
# Processing batch 62/90
# Processing batch 63/90
# Processing batch 64/90
# Processing batch 65/90
# Processing batch 66/90
# Processing batch 67/90
# Processing batch 68/90
# Processing batch 69/90
# Processing batch 70/90
# Processing batch 71/90
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AACT.W?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AACT.W&crumb=3JMyOGxXE8v
# Error processing ticker AACT.W: 'NoneType' object has no attribute 'update'
# Processing batch 72/90
# Processing batch 73/90
# Processing batch 74/90
# Error processing ticker SGRP: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ITAN: Too Many Requests. Rate limited. Try after a while.
# Processing batch 75/90
# Error processing ticker MWA: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker MUSA: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker MYE: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker MYRG: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker MYGN: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NBR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker QQQM: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NTRA: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NSI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NBHC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FIZZ: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NFG: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker IGIC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NHC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker EYE: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NESR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NGVC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker AVXL: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NAVI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NBTB: Too Many Requests. Rate limited. Try after a while.
# Processing batch 76/90
# Error processing ticker PAC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FBCG: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FIGB: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FITB: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker IFS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FA: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FAF: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker KFFB: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FFIN: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FHB: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FHN: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FRME: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FXNC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FSLR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FDT: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FUNC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FWRG: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FCFS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FE: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FI: Too Many Requests. Rate limited. Try after a while.
# Processing batch 77/90
# Error processing ticker FIVE: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FIVN: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FLXS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FND: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FLS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FLR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FLYW: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FMC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FL: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HUBC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CYBR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker DHI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker MSFD: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker DAKT: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker DAN: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker DHR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker DAR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker DTST: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker DDOG: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PLAY: Too Many Requests. Rate limited. Try after a while.
# Processing batch 78/90
# Error processing ticker DWSN: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker DK: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker DELL: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker DAL: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker DLX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker DENN: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker XRAY: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HSCS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HEI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HSII: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HELE: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HLIO: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HLX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HP: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HSIC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HLF: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HES: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HPE: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HXL: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ORC: Too Many Requests. Rate limited. Try after a while.
# Processing batch 79/90
# Error processing ticker HI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HGV: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker UMAC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HNI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HLLY: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker HOLX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker SG: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FXF: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker SYNA: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker SNPS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker SNV: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker SYY: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker TMUS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker TCHP: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker BABA: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker TTWO: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker TRGP: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ETQ: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker SNX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FTFT: Too Many Requests. Rate limited. Try after a while.
# Processing batch 80/90
# Error processing ticker BST: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker TTGT: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker TDOC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker TFX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker TIXT: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker TENB: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker TS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker TNC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OTTR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OMI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OXM: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker FOXO: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PCAR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PPBI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PKG: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PD: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PLTR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PANW: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PZZA: Too Many Requests. Rate limited. Try after a while.
# Processing batch 81/90
# Error processing ticker PARR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PAR: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker UPS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PRK: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PH: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PRKS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PSN: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ITDF: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CASH: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker CMPS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PATK: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PDCO: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PTEN: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PAYX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PAYC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PCTY: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PAYO: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PYPL: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker PBF: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OFG: Too Many Requests. Rate limited. Try after a while.
# Processing batch 82/90
# Error processing ticker OCCI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OGE: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OKTA: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ODFL: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ORI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker UGA: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OLLI: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker TAP: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ZEUS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker YXT: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OMCL: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OMC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OGS: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker LAND: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker NMTC: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OKE: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ONEW: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker TNXP: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker VNRX: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ONTO: Too Many Requests. Rate limited. Try after a while.
# Processing batch 83/90
# Error processing ticker OPEN: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OPRT: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OPCH: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OSCV: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker ORCL: Too Many Requests. Rate limited. Try after a while.
# Error processing ticker OEC: Too Many Requests. Rate limited. Try after a while.
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ORN?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ORN&crumb=Edge%3A+Too+Many+Requests
# Error processing ticker ORN: 'NoneType' object has no attribute 'update'
# Processing batch 84/90
# Processing batch 85/90
# Processing batch 86/90
# Processing batch 87/90
# Processing batch 88/90
# Processing batch 89/90
# Processing batch 90/90
# Enhanced dataset has 19 columns and 2007 rows
# Data saved to enhanced_company_data.csv

# %%
en_df.tail()
# Out:
#                                 ID                              INDUSTRY  \
# 2002  9ThdbBO1CPzgl4CCs2uwRQU9DIH5                         entertainment
# 2003  PjZeL0lwqfBy3Mdz9JAWZwOOwIsb                     consumer services
# 2004  O9KpsdPIquEYFfiVHJOgBQOrd6QS                             insurance
# 2005  ePKif3bzXcOYABNSCwtZcAGLoUse  mechanical or industrial engineering
# 2006  Qhk28SodybHScQJ97BfuYwJUbTS0                                retail
#
#                   COMPANY_NAME       SIZE  FOUNDED      REGION        COUNTRY  \
# 2002                 roku inc.  1001-5000     2002  california  united states
# 2003             rollins, inc.     10001+     1948     georgia  united states
# 2004                 root inc.  1001-5000     2015        ohio  united states
# 2005  roper technologies, inc.     10001+     1981     florida  united states
# 2006         ross stores, inc.     10001+     1982  california  united states
#
#       LOCALITY         WEBSITE                           LINKEDIN_URL  \
# 2002  san jose        roku.com              linkedin.com/company/roku
# 2003   atlanta     rollins.com      linkedin.com/company/rollins-inc.
# 2004  columbus        root.com     linkedin.com/company/rootinsurance
# 2005  sarasota   ropertech.com  linkedin.com/company/roper-industries
# 2006    dublin  rossstores.com       linkedin.com/company/ross-stores
#
#       COMPANY_AGE SIZE_CATAGORY PERFORMANCE_CATEGORY  PERFORMANCE_SCORE  \
# 2002           23         large     Steady Performer               99.0
# 2003           77         large           Developing               60.0
# 2004           10         large     Steady Performer               93.5
# 2005           44         large           Developing               66.0
# 2006           43         large           Developing               72.0
#
#      T_SYMBOL  current_price    market_cap  yearly_return  volatility
# 2002     ROKU      58.459999  8.531886e+09      -0.391889   60.906372
# 2003      ROL      55.779999  2.705754e+10      33.129381   22.339347
# 2004     ROOT     129.740005  1.972048e+09     152.265224  110.907070
# 2005      ROP     557.239990  5.983922e+10       6.294555   21.307624
# 2006     ROST     139.630005  4.591509e+10       7.067430   24.694364

# %%
save_df_to_snowflake(en_df)
# Out:
# Connected to Snowflake successfully!
# Table OPPORTUNITY_ANALYSIS.MARKET_ANALYSIS.LARGE_COMPANY_DATA_FINAL created or replaced.
# ✅ Successfully inserted 2007 rows into OPPORTUNITY_ANALYSIS.MARKET_ANALYSIS.LARGE_COMPANY_DATA_FINAL

# %%
import pandas as pd
import finnhub

#list of available exchanges

df=pd.read_html("https://docs.google.com/spreadsheets/d/1I3pBxjfXB056-g_JYf_6o3Rns3BV2kMGG1nCatb91ls/edit#gid=0")
df1=df[0]
exc=df1.loc[:,"A"].dropna()

exclist=[]
for i in exc:
    exclist.append(str(i))
exclist=exclist[1:] #take out "name" from the list

#retrieve tickers from every exchange available
tickers=[]
finnhub_client = finnhub.Client(api_key="c46qn9iad3iagvmhdk7g")
for exchange in exclist:
    listofdicts=finnhub_client.stock_symbols(exchange)
    for dicts in listofdicts:
        tickers.append(dicts['symbol'])

print("You just got a list of %s tickers worldwide." % len(tickers), tickers)

# %%
import time
import pandas as pd
import yfinance as yf
from get_all_tickers.get_tickers import get_tickers

tickers_list = get_tickers()

tickers_list = tickers_list[:50]

# Initialize an empty list to store the data.
data = []

for ticker in tickers_list:
    try:
        stock = yf.Ticker(ticker)
        info = stock.info  # Retrieve the info dictionary from yfinance
        
        # Extract the company name and market capitalization.
        company_name = info.get('longName', 'N/A')
        market_cap = info.get('marketCap', 'N/A')
        
        # Append the data as a dictionary.
        data.append({
            'Ticker': ticker,
            'Company Name': company_name,
            'Market Cap': market_cap
        })
        
        # Pause briefly to respect rate limits.
        time.sleep(0.1)
    except Exception as e:
        print(f"Error retrieving data for {ticker}: {e}")
        continue

# Create a DataFrame from the list of dictionaries.
# Out:
# c:\Users\yohan\anaconda3\envs\final_proj_1\Lib\site-packages\get_all_tickers\get_tickers.py:95: SyntaxWarning: invalid escape sequence '\.'
#   df = df[~df['Symbol'].str.contains("\.|\^")]
# c:\Users\yohan\anaconda3\envs\final_proj_1\Lib\site-packages\get_all_tickers\get_tickers.py:140: SyntaxWarning: invalid escape sequence '\.'
#   df_filtered = df[~df['Symbol'].str.contains("\.|\^")]
# c:\Users\yohan\anaconda3\envs\final_proj_1\Lib\site-packages\get_all_tickers\get_tickers.py:147: SyntaxWarning: invalid escape sequence '\.'
#   df = df[~df['Symbol'].str.contains("\.|\^")]
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[2], line 6
#       3 import yfinance as yf
#       4 from get_all_tickers.get_tickers import get_tickers
# ----> 6 tickers_list = get_tickers()
#       8 tickers_list = tickers_list[:50]
#      10 # Initialize an empty list to store the data.
#
# File c:\Users\yohan\anaconda3\envs\final_proj_1\Lib\site-packages\get_all_tickers\get_tickers.py:73, in get_tickers(NYSE, NASDAQ, AMEX)
#      71 tickers_list = []
#      72 if NYSE:
# ---> 73     tickers_list.extend(__exchange2list('nyse'))
#      74 if NASDAQ:
#      75     tickers_list.extend(__exchange2list('nasdaq'))
#
# File c:\Users\yohan\anaconda3\envs\final_proj_1\Lib\site-packages\get_all_tickers\get_tickers.py:138, in __exchange2list(exchange)
#     137 def __exchange2list(exchange):
# --> 138     df = __exchange2df(exchange)
#     139     # removes weird tickers
#     140     df_filtered = df[~df['Symbol'].str.contains("\.|\^")]
#
# File c:\Users\yohan\anaconda3\envs\final_proj_1\Lib\site-packages\get_all_tickers\get_tickers.py:134, in __exchange2df(exchange)
#     132 response = requests.get('https://old.nasdaq.com/screening/companies-by-name.aspx', headers=headers, params=params(exchange))
#     133 data = io.StringIO(response.text)
# --> 134 df = pd.read_csv(data, sep=",")
#     135 return df
#
# File c:\Users\yohan\anaconda3\envs\final_proj_1\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\yohan\anaconda3\envs\final_proj_1\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\yohan\anaconda3\envs\final_proj_1\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\yohan\anaconda3\envs\final_proj_1\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 9, saw 2

# %%
from pytickersymbols import PyTickerSymbols

stock_data = PyTickerSymbols()
german_stocks = stock_data.get_stocks_by_index('DAX')
uk_stocks = stock_data.get_stocks_by_index('FTSE 100')

print(list(uk_stocks))
# Out:
# [{'name': '3i Group PLC', 'symbol': 'III', 'country': 'United Kingdom', 'indices': ['FTSE 100'], 'industries': ['Banking & Investment Services', 'Investment Banking & Investment Services', 'Financials', 'Investment Management & Fund Operators'], 'symbols': [{'yahoo': 'IGQ5.F', 'google': 'FRA:IGQ5', 'currency': 'EUR'}, {'yahoo': 'TGOPY', 'google': 'OTCMKTS:TGOPY', 'currency': 'USD'}, {'yahoo': 'III.L', 'google': 'LON:III', 'currency': 'GBP'}, {'yahoo': 'IGQ.F', 'google': 'FRA:IGQ', 'currency': 'EUR'}, {'yahoo': 'TGOPF', 'google': 'OTCMKTS:TGOPF', 'currency': 'USD'}], 'metadata': {'founded': 1945, 'employees': 244}, 'isins': ['GB00B1YW4409'], 'akas': []}, {'name': 'Admiral Group PLC', 'symbol': 'ADM', 'country': 'United Kingdom', 'indices': ['FTSE 100'], 'industries': ['Insurance', 'Property & Casualty Insurance', 'Financials'], 'symbols': [{'yahoo': 'FLN.F', 'google': 'FRA:FLN', 'currency': 'EUR'}, {'yahoo': 'ADM.L', 'google': 'LON:ADM', 'currency': 'GBP'}, {'yahoo': 'AMIGY', 'google': 'OTCMKTS:AMIGY', 'currency': 'USD'}, {'yahoo': 'AMIGF', 'google': 'OTCMKTS:AMIGF', 'currency': 'USD'}], 'metadata': {'founded': 1991, 'employees': 3000}, 'isins': ['GB00B02J6398'], 'akas': []}, {'name': 'Anglo American PLC', 'symbol': 'AAL', 'country': 'United Kingdom', 'indices': ['FTSE 100'], 'industries': ['Metals & Mining', 'Mineral Resources', 'Basic Materials', 'Integrated Mining'], 'symbols': [{'yahoo': 'NGLD.F', 'google': 'FRA:NGLD', 'currency': 'EUR'}, {'yahoo': 'AGPPF', 'google': 'OTCMKTS:AGPPF', 'currency': 'USD'}, {'yahoo': 'NGLOY', 'google': 'OTCMKTS:NGLOY', 'currency': 'USD'}, {'yahoo': 'NGLB.F', 'google': 'FRA:NGLB', 'currency': 'EUR'}, {'yahoo': 'AAL.L', 'google': 'LON:AAL', 'currency': 'GBP'}], 'metadata': {'founded': 1917, 'employees': 90000}, 'isins': ['GB00B1XZS820'], 'akas': []}, {'name': 'Antofagasta PLC', 'symbol': 'ANTO', 'country': 'United Kingdom', 'indices': ['FTSE 100'], 'industries': ['Metals & Mining', 'Mineral Resources', 'Specialty Mining & Metals', 'Basic Materials'], 'symbols': [{'yahoo': 'FG1.F', 'google': 'FRA:FG1', 'currency': 'EUR'}, {'yahoo': 'ANFGF', 'google': 'OTCMKTS:ANFGF', 'currency': 'USD'}, {'yahoo': 'ANTO.L', 'google': 'LON:ANTO', 'currency': 'GBP'}], 'metadata': {'founded': 1888, 'employees': 5427}, 'isins': ['GB0000456144'], 'akas': []}, {'name': 'Ashtead Group PLC', 'symbol': 'AHT', 'country': 'United Kingdom', 'indices': ['FTSE 100'], 'industries': ['Business Support Services', 'Industrials', 'Professional & Commercial Services', 'Industrial & Commercial Services'], 'symbols': [{'yahoo': 'AHT.F', 'google': 'FRA:AHT', 'currency': 'EUR'}, {'yahoo': 'AHT', 'google': 'OTCMKTS:AHT', 'currency': 'USD'}, {'yahoo': '0LC.F', 'google': 'FRA:0LC', 'currency': 'EUR'}, {'yahoo': 'AHT.L', 'google': 'LON:AHT', 'currency': 'GBP'}, {'yahoo': 'ASHTY', 'google': 'OTCMKTS:ASHTY', 'currency': 'USD'}, {'yahoo': 'ASHTF', 'google': 'OTCMKTS:ASHTF', 'currency': 'USD'}, {'yahoo': '0LCA.F', 'google': 'FRA:0LCA', 'currency': 'EUR'}], 'metadata': {'founded': 1947, 'employees': 13233}, 'isins': ['GB0000536739'], 'akas': []}, {'name': 'Associated British Foods PLC', 'symbol': 'ABF', 'country': 'United Kingdom', 'indices': ['FTSE 100'], 'industries': ['Food & Beverages', 'Consumer Non-Cyclicals', 'Food Processing', 'Food & Tobacco'], 'symbols': [{'yahoo': 'ABF.F', 'google': 'FRA:ABF', 'currency': 'EUR'}, {'yahoo': 'ABF', 'google': 'OTCMKTS:ABF', 'currency': 'USD'}, {'yahoo': 'AFO1.F', 'google': 'FRA:AFO1', 'currency': 'EUR'}, {'yahoo': 'ABF.L', 'google': 'LON:ABF', 'currency': 'GBP'}, {'yahoo': 'ASBFY', 'google': 'OTCMKTS:ASBFY', 'currency': 'USD'}, {'yahoo': 'AFO2.F', 'google': 'FRA:AFO2', 'currency': 'EUR'}, {'yahoo': 'ASBFF', 'google': 'OTCMKTS:ASBFF', 'currency': 'USD'}], 'metadata': {'founded': 1935, 'employees': 133000}, 'isins': ['GB0006731235'], 'akas': []}, {'name': 'AstraZeneca PLC', 'symbol': 'AZN', 'country': 'United Kingdom', 'indices': ['FTSE 100', 'NASDAQ 100', 'OMX Stockholm 30'], 'industries': ['Pharmaceuticals ...

# %%
from pytickersymbols import PyTickerSymbols

# Initialize the PyTickerSymbols object
stock_data = PyTickerSymbols()

# Retrieve stocks for each index
sp500_stocks = list(stock_data.get_stocks_by_index('S&P 500'))
dowjones_stocks = list(stock_data.get_stocks_by_index('DOW JONES'))
nasdaq100_stocks = list(stock_data.get_stocks_by_index('NASDAQ 100'))

# Combine all stocks into a single list
us_stocks = sp500_stocks + dowjones_stocks + nasdaq100_stocks

# Extract unique ticker symbols
tickers = list({stock['symbol'] for stock in us_stocks})

# %%
import ftplib
import pandas as pd
from io import StringIO

def fetch_us_listed_tickers():
    ftp = ftplib.FTP('ftp.nasdaqtrader.com')
    ftp.login()
    ftp.encoding = 'utf-8'
    ftp.cwd('SymbolDirectory')

    files = ["nasdaqlisted.txt", "otherlisted.txt"]
    all_dfs = []

    for file in files:
        buffer = []
        ftp.retrlines(f"RETR {file}", buffer.append)
        content = "\n".join(buffer)
        
        df = pd.read_csv(StringIO(content), sep="|")
        df = df[:-1]  # remove footer row
        all_dfs.append(df)

    ftp.quit()

    # Combine and return a unified DataFrame with standardized columns
    combined_df = pd.concat(all_dfs, ignore_index=True)
    combined_df.rename(columns={'Symbol': 'ticker', 'Security Name': 'company_name'}, inplace=True)
    return combined_df[['ticker', 'company_name']].drop_duplicates()

# %%
import yfinance as yf
import time

def enrich_with_yfinance(df: pd.DataFrame, sleep_time: float = 0.5) -> pd.DataFrame:
    """
    Adds 'yf_company_name' and 'market_cap' columns to the DataFrame using yfinance.
    Original 'company_name' from NASDAQ remains untouched for reference.
    """
    enriched_data = []

    for _, row in df.iterrows():
        ticker = row['ticker']
        try:
            stock = yf.Ticker(ticker)
            info = stock.info
            yf_name = info.get('longName', 'N/A')
            market_cap = info.get('marketCap', 'N/A')
        except Exception as e:
            print(f"Error for {ticker}: {e}")
            yf_name = "Error"
            market_cap = None
        
        enriched_data.append({
            'ticker': ticker,
            'original_name': row['company_name'],
            'yf_company_name': yf_name,
            'market_cap': market_cap
        })

        time.sleep(sleep_time)  # avoid rate limiting

    return pd.DataFrame(enriched_data)

# %%
tickers_df = fetch_us_listed_tickers()

# %%
tickers_df = tickers_df.drop_duplicates(subset=['ticker'])  # Remove duplicates based on ticker

# %%
tickers_df.head()
# Out:
#   ticker                                       company_name
# 0   AACB  Artius II Acquisition Inc. - Class A Ordinary ...
# 1  AACBR                Artius II Acquisition Inc. - Rights
# 2  AACBU                 Artius II Acquisition Inc. - Units
# 3   AACG  ATA Creativity Global - American Depositary Sh...
# 4   AADR                AdvisorShares Dorsey Wright ADR ETF

# %%
enriched_df = enrich_with_yfinance(tickers_df)
# Out:
# 500 Server Error: Internal Server Error for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LUCYW?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LUCYW&crumb=fhSyczRYun3
# Error for LUCYW: 'NoneType' object has no attribute 'update'
# Error for nan: 'float' object has no attribute 'upper'
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ZAZZT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ZAZZT&crumb=fhSyczRYun3
# Error for ZAZZT: 'NoneType' object has no attribute 'update'
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ZBZZT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ZBZZT&crumb=fhSyczRYun3
# Error for ZBZZT: 'NoneType' object has no attribute 'update'
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ZCZZT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ZCZZT&crumb=fhSyczRYun3
# Error for ZCZZT: 'NoneType' object has no attribute 'update'
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ZXYZ.A?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ZXYZ.A&crumb=fhSyczRYun3
# Error for ZXYZ.A: 'NoneType' object has no attribute 'update'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# ...
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# Error for nan: 'float' object has no attribute 'upper'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 enriched_df = enrich_with_yfinance(tickers_df)
#
# Cell In[24], line 30, in enrich_with_yfinance(df, sleep_time)
#      21         market_cap = None
#      23     enriched_data.append({
#      24         'ticker': ticker,
#      25         'original_name': row['company_name'],
#      26         'yf_company_name': yf_name,
#      27         'market_cap': market_cap
#      28     })
# ---> 30     time.sleep(sleep_time)  # avoid rate limiting
#      32 return pd.DataFrame(enriched_data)
#
# KeyboardInterrupt:

# %%
def filter_valid_companies(df: pd.DataFrame):
    """
    Filters the DataFrame to keep only rows with valid company names and market cap.
    """
    return df[
        (df['yf_company_name'].notna()) &
        (df['yf_company_name'] != 'N/A') &
        (df['yf_company_name'] != 'Error') &
        (df['market_cap'] != 'N/A')
    ].reset_index(drop=True)

# %%
enriched_df
# Out:
# 100

# %%
filtered_df = filter_valid_companies(enriched_df)
filtered_df.head()
# Out:
#   ticker                                      original_name  \
# 0   AACB  Artius II Acquisition Inc. - Class A Ordinary ...
# 1  AACBU                 Artius II Acquisition Inc. - Units
# 2   AACG  ATA Creativity Global - American Depositary Sh...
# 3    AAL       American Airlines Group, Inc. - Common Stock
# 4   AAME       Atlantic American Corporation - Common Stock
#
#                                      yf_company_name  market_cap
# 0  Artius II Acquisition Inc. Class A Ordinary Sh...   248854880
# 1                   Artius II Acquisition Inc. Units   253260512
# 2                              ATA Creativity Global    30211798
# 3                       American Airlines Group Inc.  6358759936
# 4                      Atlantic American Corporation    26931038

# %%
filtered_df.to_csv('filtered_us_companies.csv', index=False)
